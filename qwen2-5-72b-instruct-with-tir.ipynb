# %% [markdown]
# References
#
# - https://www.kaggle.com/code/richolson/ai-math-olympiad-qwen2-5-72b for showing how to submit
# - https://www.kaggle.com/code/abdullahmeda/load-72b-awq-model-using-vllm-on-l4-x4
# - https://www.kaggle.com/code/huikang/qwen2-5-math-1-5b-instruct

# %%
import os  # operating system
import gc  # garbage collector
import time
import warnings

import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import polars as pl  # polars

import torch  # pytorch
import kaggle_evaluation.aimo_2_inference_server

pd.set_option('display.max_colwidth', None)  # display all columns
cutoff_time = time.time() + (4 * 60 + 30) * 60  # 4 hours 30 minutes from now

# %%
# VLLM model and sampling parameters for inference and evaluation
from vllm import LLM, SamplingParams

# ignore warnings
warnings.simplefilter('ignore')

# use all GPUs available on the Kaggle notebook (4 GPUs) for tensor parallelism with PyTorch and VLLM model inference
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"
# disable tokenizers parallelism to avoid deadlocks with PyTorch tensor parallelism
os.environ["TOKENIZERS_PARALLELISM"] = "false"


# clean memory (RAM and GPU memory) to avoid memory leaks and out-of-memory errors (e.g., due to PyTorch tensor parallelism)
# and improve performance (e.g., by reducing memory fragmentation) and stability (e.g., by avoiding memory leaks) of the VLLM model
def clean_memory(deep=False):
    gc.collect()  # garbage collector (RAM)
    if deep:
        # memory allocator (RAM) for PyTorch tensors
        ctypes.CDLL("libc.so.6").malloc_trim(0)
    # memory allocator (GPU) for PyTorch tensors
    torch.cuda.empty_cache()


llm_model_pth = '/kaggle/input/qwen2.5/transformers/72b-instruct-awq/1'

# Load the VLLM model for inference
llm = LLM(
    llm_model_pth,
    dtype="half",  # The data type for the model weights and activations
    max_num_seqs=8,  # Maximum number of sequences per iteration. Default is 256
    max_model_len=4096,  # Model context length
    trust_remote_code=
    True,  # Trust remote code (e.g., from HuggingFace) when downloading the model and tokenizer
    tensor_parallel_size=
    4,  # The number of GPUs to use for distributed execution with tensor parallelism
    gpu_memory_utilization=
    0.95,  # The ratio (between 0 and 1) of GPU memory to reserve for the model
    seed=2024,  # Random seed for reproducibility
)
# Out:
# 2024-11-08 08:09:40,206	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# INFO 11-08 08:10:06 awq_marlin.py:97] The model is convertible to awq_marlin during runtime. Using awq_marlin kernel.
# INFO 11-08 08:10:06 config.py:905] Defaulting to use mp for distributed inference
# INFO 11-08 08:10:06 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='/kaggle/input/qwen2.5/transformers/72b-instruct-awq/1', speculative_config=None, tokenizer='/kaggle/input/qwen2.5/transformers/72b-instruct-awq/1', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=4, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=awq_marlin, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=2024, served_model_name=/kaggle/input/qwen2.5/transformers/72b-instruct-awq/1, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, mm_processor_kwargs=None)
# WARNING 11-08 08:10:07 multiproc_gpu_executor.py:53] Reducing Torch parallelism from 24 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 11-08 08:10:07 custom_cache_manager.py:17] Setting Triton cache manager to: vllm.triton_utils.custom_cache_manager:CustomCacheManager
# (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) (VllmWorkerProcess pid=481) INFO 11-08 08:10:08 multiproc_worker_utils.py:215] Worker ready; awaiting tasks
# INFO 11-08 08:10:08 multiproc_worker_utils.py:215] Worker ready; awaiting tasks
# INFO 11-08 08:10:08 multiproc_worker_utils.py:215] Worker ready; awaiting tasks
# INFO 11-08 08:10:09 utils.py:1008] Found nccl from library libnccl.so.2
# INFO 11-08 08:10:09 pynccl.py:63] vLLM is using nccl==2.20.5
# (VllmWorkerProcess pid=481) (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) INFO 11-08 08:10:09 utils.py:1008] Found nccl from library libnccl.so.2
# INFO 11-08 08:10:09 utils.py:1008] Found nccl from library libnccl.so.2
# INFO 11-08 08:10:09 utils.py:1008] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=481) (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) INFO 11-08 08:10:09 pynccl.py:63] vLLM is using nccl==2.20.5
# INFO 11-08 08:10:09 pynccl.py:63] vLLM is using nccl==2.20.5
# INFO 11-08 08:10:09 pynccl.py:63] vLLM is using nccl==2.20.5
# WARNING 11-08 08:10:10 custom_all_reduce.py:132] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorkerProcess pid=483) (VllmWorkerProcess pid=481) (VllmWorkerProcess pid=482) WARNING 11-08 08:10:10 custom_all_reduce.py:132] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 11-08 08:10:10 custom_all_reduce.py:132] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# WARNING 11-08 08:10:10 custom_all_reduce.py:132] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# INFO 11-08 08:10:10 shm_broadcast.py:241] vLLM message queue communication handle: Handle(connect_ip='127.0.0.1', local_reader_ranks=[1, 2, 3], buffer=<vllm.distributed.device_communicators.shm_broadcast.ShmRingBuffer object at 0x7a2aea79f700>, local_subscribe_port=57313, remote_subscribe_port=None)
# INFO 11-08 08:10:10 model_runner.py:1056] Starting to load model /kaggle/input/qwen2.5/transformers/72b-instruct-awq/1...
# (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) INFO 11-08 08:10:10 model_runner.py:1056] Starting to load model /kaggle/input/qwen2.5/transformers/72b-instruct-awq/1...
# (VllmWorkerProcess pid=481) INFO 11-08 08:10:10 model_runner.py:1056] Starting to load model /kaggle/input/qwen2.5/transformers/72b-instruct-awq/1...
# INFO 11-08 08:10:10 model_runner.py:1056] Starting to load model /kaggle/input/qwen2.5/transformers/72b-instruct-awq/1...
# Loading safetensors checkpoint shards:   0% Completed | 0/11 [00:00<?, ?it/s]
# (VllmWorkerProcess pid=483) INFO 11-08 08:14:42 model_runner.py:1067] Loading model weights took 9.7875 GB
# INFO 11-08 08:14:42 model_runner.py:1067] Loading model weights took 9.7875 GB
# (VllmWorkerProcess pid=481) INFO 11-08 08:14:42 model_runner.py:1067] Loading model weights took 9.7875 GB
# (VllmWorkerProcess pid=482) INFO 11-08 08:14:42 model_runner.py:1067] Loading model weights took 9.7875 GB
# INFO 11-08 08:14:50 distributed_gpu_executor.py:57] # GPU blocks: 8633, # CPU blocks: 3276
# INFO 11-08 08:14:50 distributed_gpu_executor.py:61] Maximum concurrency for 4096 tokens per request: 33.72x
# INFO 11-08 08:14:53 model_runner.py:1395] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 11-08 08:14:53 model_runner.py:1399] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# (VllmWorkerProcess pid=483) (VllmWorkerProcess pid=481) (VllmWorkerProcess pid=482) INFO 11-08 08:14:53 model_runner.py:1395] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 11-08 08:14:53 model_runner.py:1395] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 11-08 08:14:53 model_runner.py:1395] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# (VllmWorkerProcess pid=481) (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) INFO 11-08 08:14:53 model_runner.py:1399] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 11-08 08:14:53 model_runner.py:1399] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 11-08 08:14:53 model_runner.py:1399] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 11-08 08:14:58 model_runner.py:1523] Graph capturing finished in 5 secs.
# (VllmWorkerProcess pid=482) (VllmWorkerProcess pid=483) INFO 11-08 08:14:58 model_runner.py:1523] Graph capturing finished in 5 secs.
# (VllmWorkerProcess pid=481) INFO 11-08 08:14:58 model_runner.py:1523] Graph capturing finished in 5 secs.
# INFO 11-08 08:14:58 model_runner.py:1523] Graph capturing finished in 5 secs.

# %%
# Get the tokenizer for the VLLM model
tokenizer = llm.get_tokenizer()

# %%
import re  # regular expressions
import keyword  # Python keywords


# Extract Python code from the text using regular expressions (regex) and return it as a string separated by two newlines (\n\n) between each code block
# (e.g., "code1\n\n\ncode2\n\n\ncode3")
def extract_python_code(text):
    # Regular expression pattern for Python code blocks
    pattern = r'```python\s*(.*?)\s*```'
    # Find all matches of the pattern in the text
    matches = re.findall(pattern, text, re.DOTALL)
    # Return the Python code blocks as a string separated by two newlines
    return "\n\n".join(matches)  # Join all matches with two newlines


# Process the Python code by adding import statements and printing variables that are not inside any indentation (e.g., "x = 42" will be printed as "x=42")
# and return the processed code as a string separated by newlines (\n) between each row (e.g., "row1\nrow2\nrow3")
def process_python_code(query):
    # Add import statements
    # Also print variables if they are not inside any indentation
    query = "import math\nimport numpy as np\nimport sympy as sp\n" + query
    # Split the query into rows
    current_rows = query.strip().split("\n")
    new_rows = []
    for row in current_rows:
        # Add the current row
        new_rows.append(row)
        if not row.startswith(" ") and "=" in row:
            # Get the variable name
            variables_to_print = row.split("=")[0].strip()
            # Split multiple variables
            for variable_to_print in variables_to_print.split(","):
                # Remove leading/trailing spaces
                variable_to_print = variable_to_print.strip()
                # Check if the variable is a valid identifier and not a Python keyword
                if variable_to_print.isidentifier(
                ) and not keyword.iskeyword(variable_to_print):
                    if row.count("(") == row.count(")") and row.count(
                            "[") == row.count("]"):
                        # TODO: use some AST to parse code
                        new_rows.append(
                            f'\ntry:\n    print(f"{variable_to_print}={{str({variable_to_print})[:100]}}")\nexcept:\n    pass\n'
                        )
    return "\n".join(new_rows)


# Extract text inside "boxed" curly braces {text} using regular expressions (regex) and return it as a string or an empty string if no match is found (e.g., "{text}" will return "text")
def extract_boxed_text(text):
    # Regular expression pattern for boxed text
    pattern = r'oxed{(.*?)}'
    # Find all matches of the pattern in the text
    matches = re.findall(pattern, text)
    if not matches:
        return ""
    # Return the first match
    return matches[0]


from collections import Counter  # Counter for counting occurrences of elements in a list
import random  # random numbers and shuffling lists (e.g., for random sampling)


# Select the most common answer from a list of answers and return it as an integer (e.g., [1, 2, 2, 3, 3, 3] will return 3)
def select_answer(answers):
    # Counter for counting occurrences of elements
    counter = Counter()
    for answer in answers:
        try:
            # Check if the answer is an integer
            if int(answer) == float(answer):
                # Add the answer to the counter with a small random noise to break ties
                counter[int(answer)] += 1 + random.random() / 1_000
        except:
            pass
    if not counter:
        # Return the default answer if no valid answers are found
        return 210
    # Select the most common answer from the counter
    _, answer = sorted([(v, k) for k, v in counter.items()], reverse=True)[0]
    # Return the answer modulo 1000 (e.g., 1000 will be returned as 0)
    return answer % 1000

# %%
import os
import tempfile  # temporary files and directories
import subprocess  # subprocesses


# Python Read-Eval-Print Loop (REPL) for executing Python code with a timeout using subprocesses and temporary files and directories for security and resource management
class PythonREPL:

    def __init__(self, timeout=5):
        # Timeout for code execution in seconds
        self.timeout = timeout

    def __call__(self, query):
        # Create a temporary directory
        with tempfile.TemporaryDirectory() as temp_dir:
            # Temporary Python file path
            temp_file_path = os.path.join(temp_dir, "tmp.py")
            # Write the query to the temporary file
            with open(temp_file_path, "w", encoding="utf-8") as f:
                f.write(query)

            try:
                # Execute the Python file with a timeout
                result = subprocess.run(
                    ["python3", temp_file_path],
                    # Capture stdout and stderr
                    capture_output=True,
                    # Do not raise an exception on non-zero exit codes
                    check=False,
                    # Return stdout and stderr as text
                    text=True,
                    # Timeout for code execution
                    timeout=self.timeout,
                )
            except subprocess.TimeoutExpired:
                return False, f"Execution timed out after {self.timeout} seconds."

            stdout = result.stdout.strip()
            stderr = result.stderr.strip()

            if result.returncode == 0:
                return True, stdout
            else:
                # Process the error message to remove the temporary file path
                # This makes the error message cleaner and more user-friendly
                error_lines = stderr.split("\n")
                cleaned_errors = []
                for line in error_lines:
                    if temp_file_path in line:
                        # Remove the path from the error line
                        line = line.replace(temp_file_path, "<temporary_file>")
                    cleaned_errors.append(line)
                cleaned_error_msg = "\n".join(cleaned_errors)
                # Include stdout in the error case
                combined_output = f"{stdout}\n{cleaned_error_msg}" if stdout else cleaned_error_msg
                return False, combined_output

# %%
# Sampling parameters for the VLLM model for generating messages
sampling_params = SamplingParams(
    # Softmax temperature for sampling. Must be greater than 0. Default is 1.0 (argmax sampling) -> randomness of the sampling
    temperature=1.0,
    # Minimum token probability for sampling. Must be in the range [0, 1]. Default is 0.01
    min_p=0.01,
    # Skip special tokens (e.g., <PAD>, <BOS>, <EOS>) in the output. Default is True
    skip_special_tokens=True,
    # Maximum number of tokens to generate. Must be greater than 0. Default is 2048
    max_tokens=2400,
    # Stop sequence for sampling. Default is None
    stop=["```\n"],
    # Include the stop sequence in the output. Default is True
    include_stop_str_in_output=True,
)


# Generate a message using the VLLM model and return the generated message as a string (e.g., "Hello, world!")
# or an empty string if no message is generated (e.g., if the input is empty)
def batch_message_generate(list_of_messages) -> list[list[dict]]:

    list_of_texts = [
        # Apply the chat template to each conversation and add the generation prompt to each message in the conversation
        # (e.g., "role: user\ncontent: Hello, world!") and return the list of texts as a list of strings
        # (e.g., ["role: user\ncontent: Hello, world!", "role: assistant\ncontent: Hi!"])
        tokenizer.apply_chat_template(conversation=messages,
                                      tokenize=False,
                                      add_generation_prompt=True)
        for messages in list_of_messages
    ]
    # Generate messages using the VLLM model with the list of texts and sampling parameters
    request_output = llm.generate(
        prompts=list_of_texts,
        sampling_params=sampling_params,
    )

    for messages, single_request_output in zip(list_of_messages,
                                               request_output):
        # print()
        # print(single_request_output.outputs[0].text)
        # print()
        messages.append({
            'role': 'assistant',
            'content': single_request_output.outputs[0].text
        })

    return list_of_messages

# %%
# Filter messages that contain boxed text and extract the boxed text as the answer
def batch_message_filter(
        list_of_messages) -> tuple[list[list[dict]], list[str]]:
    extracted_answers = []
    list_of_messages_to_keep = []
    for messages in list_of_messages:
        answer = extract_boxed_text(messages[-1]['content'])
        if answer:
            extracted_answers.append(answer)
        else:
            list_of_messages_to_keep.append(messages)
    return list_of_messages_to_keep, extracted_answers

# %%
# Execute Python code in messages and return the output as a string (e.g., "Hello, world!")
# or an empty string if no output is generated (e.g., if the input is empty)
# or an error occurs (e.g., syntax error) during code execution (e.g., "SyntaxError: invalid syntax")
# or if the code execution times out (e.g., "Execution timed out after 5 seconds.")
# or if the code execution fails (e.g., "Execution failed with exit code 1.")
# or if the code execution is successful but no output is generated (e.g., "Execution successful but no output.")
# or if the code execution is successful but the output is empty (e.g., "Execution successful but empty output.")
# or if the code execution is successful but the output is too long (e.g., "Execution successful but output is too long.")
# or if the code execution is successful but the output is too short (e.g., "Execution successful but output is too short.")
# or if the code execution is successful but the output is invalid (e.g., "Execution successful but invalid output.")
# or if the code execution is successful but the output is not a string (e.g., "Execution successful but output is not a string.")
# or if the code execution is successful but the output is not a valid answer
def batch_message_execute(list_of_messages) -> list[list[dict]]:
    for messages in list_of_messages:
        python_code = extract_python_code(messages[-1]['content'])
        python_code = process_python_code(python_code)
        # print('\n\n' + python_code + '\n\n')
        try:
            print('c', end='')
            is_successful, output = PythonREPL()(python_code)
            if is_successful:
                print('o', end='')
            else:
                print('e', end='')
        except Exception as e:
            print('f', end='')
            output = str(e)
        print(python_code)
        print()
        print(output)
        print("\n\n")
        messages.append({
            'role': 'user',
            'content': "```output\n" + output + "\n```"
        })
    print()
    return list_of_messages

# %%
def create_starter_messages(question, index):
    cycle_size = 2
    if False:
        pass
    elif index % cycle_size == 1:
        # https://github.com/QwenLM/Qwen2.5-Math?tab=readme-ov-file#-hugging-face-transformers
        return [{
            "role":
            "system",
            "content":
            "Please reason step by step, and put your final answer within \\boxed{}."
        }, {
            "role": "user",
            "content": question
        }]
    else:
        # https://github.com/QwenLM/Qwen2.5-Math?tab=readme-ov-file#-hugging-face-transformers
        return [{
            "role":
            "system",
            "content":
            "Please integrate natural language reasoning with programs to solve the problem above, and put your final answer within \\boxed{}."
        }, {
            "role":
            "user",
            "content":
            question + "\n\nBegin your answer by importing sympy."
        }]

# %%
"""
Dynamic Batch Size Optimization
-----------------------------
The following implementation replaces the static batch size of 32 with a dynamic batch sizing mechanism.

Rationale:
- Fixed batch sizes can be suboptimal as GPU memory availability varies during execution
- Large static batch sizes may cause OOM errors or memory fragmentation
- Small static batch sizes may underutilize available resources
- Memory requirements per conversation can vary based on problem complexity

Benefits:
- Adaptive resource utilization based on real-time GPU memory availability
- Reduced risk of OOM errors during long running sessions
- Better throughput by maximizing parallel processing when possible
- More resilient to varying problem complexities

Implementation notes:
- Uses 80% of available GPU memory to leave headroom for fluctuations
- Sets reasonable min/max bounds (8-48) to maintain stability
- Falls back to conservative batch size (16) if memory detection fails
- Considers multi-GPU setups by checking all available devices

Last modified: November 2024
"""


def get_optimal_batch_size():
    """
    Dynamically determine the optimal batch size for parallel message processing
    based on available GPU memory across all devices.
    
    The function:
    1. Checks available memory across all GPU devices
    2. Calculates safe batch size using conservative memory estimates
    3. Applies bounds to ensure stable execution
    
    Returns:
        int: Optimal batch size between 8 and 48
        
    Note:
        - Assumes ~0.5GB memory usage per conversation
        - Uses 80% of available memory as safety margin
        - Falls back to batch size 16 if memory detection fails
    """
    try:
        # Get available GPU memory
        gpu_memory = []
        for i in range(torch.cuda.device_count()):
            total_memory = torch.cuda.get_device_properties(i).total_memory
            allocated_memory = torch.cuda.memory_allocated(i)
            free_memory = total_memory - allocated_memory
            gpu_memory.append(free_memory)

        # Use the minimum free memory across all GPUs
        min_free_memory = min(gpu_memory)

        # Calculate batch size based on free memory
        # Conservative estimate: assume each conversation requires about 0.5GB
        memory_per_conversation = 0.5 * (1024**3)  # 0.5GB in bytes
        optimal_batch_size = int(
            (min_free_memory * 0.8) /
            memory_per_conversation)  # Use 80% of free memory

        # Ensure batch size is within reasonable bounds
        optimal_batch_size = max(8, min(48, optimal_batch_size))

        return optimal_batch_size
    except Exception as e:
        print(f"Error calculating batch size: {e}")
        return 16  # Default fallback batch size

# %%
def predict_for_question(question: str) -> int:
    import os
    # only run this code if it's not a competition rerun
    if not os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
        # only run this code if the question is not the example question from the competition page (to avoid wasting time)
        if question != "Triangle $ABC$ has side length $AB = 120$ and circumradius $R = 100$. Let $D$ be the foot of the perpendicular from $C$ to the line $AB$. What is the greatest possible length of segment $CD$?":
            return 210
    # check if the time limit has been reached
    if time.time() > cutoff_time:
        return 210

    question += "\nIf the final answer is a number larger than 1 million, take modulo 1000."
    print(question)

    # Dynamic batch size instead of fixed 32 for parallel message processing (e.g., for tensor parallelism) based on available GPU memory across all devices (e.g., 8-48 conversations in parallel)
    batch_size = get_optimal_batch_size()
    list_of_messages = [
        create_starter_messages(question, index) for index in range(batch_size)
    ]

    all_extracted_answers = []
    # 4 rounds of message generation, filtering, and execution
    for _ in range(4):
        # Generate messages using the VLLM model
        list_of_messages = batch_message_generate(list_of_messages)
        # Filter messages that contain boxed text and extract the boxed text as the answer
        list_of_messages, extracted_answers = batch_message_filter(
            list_of_messages)
        # Extend the list of extracted answers
        all_extracted_answers.extend(extracted_answers)
        if not list_of_messages:
            break
        # Execute Python code in messages and return the output as a string
        list_of_messages = batch_message_execute(list_of_messages)

    print(all_extracted_answers)
    answer = select_answer(all_extracted_answers)
    print(answer)

    print("\n\n")
    return answer

# %%
# Replace this function with your inference code.
# The function should return a single integer between 0 and 999, inclusive.
# Each prediction (except the very first) must be returned within 30 minutes of the question being provided.
def predict(id_: pl.DataFrame,
            question: pl.DataFrame) -> pl.DataFrame | pd.DataFrame:
    # get the first element of the DataFrame
    id_ = id_.item(0)
    print("------")
    print(id_)

    # get the first element of the DataFrame
    question = question.item(0)
    answer = predict_for_question(question)
    print(question)
    print("------\n\n\n")
    return pl.DataFrame({'id': id_, 'answer': answer})

# %%
# predict_for_question("Triangle $ABC$ has side length $AB = 120$ and circumradius $R = 100$. Let $D$ be the foot of the perpendicular from $C$ to the line $AB$. What is the greatest possible length of segment $CD$?")
# Out:
# Triangle $ABC$ has side length $AB = 120$ and circumradius $R = 100$. Let $D$ be the foot of the perpendicular from $C$ to the line $AB$. What is the greatest possible length of segment $CD$?
# If the final answer is a number larger than 1 million, take modulo 1000.
# Processed prompts: 100%|██████████| 32/32 [02:55<00:00,  5.50s/it, est. speed input: 20.83 toks/s, output: 108.93 toks/s]
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at C as θ
# theta = sp.symbols('theta')
#
# try:
#     print(f"theta={str(theta)[:100]}")
# except:
#     pass
#
#
# # Using the circumradius formula R = (AB * BC * CA) / (4 * Area)
# # We can express the area of triangle ABC in terms of R and theta
# # Area = (1/2) * AB * CD
# # We also know that in a right triangle, CD = R * sin(θ)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
# CD = R * sp.sin(theta)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # The length of AB is fixed, so we need to maximize CD
# # The maximum value of sin(θ) is 1, which occurs when θ = 90 degrees or π/2 radians
# max_CD = CD.subs(theta, sp.pi/2)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression
# max_CD = sp.simplify(max_CD)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # If the final answer is larger than 1 million, take modulo 1000
# if max_CD > 1000000:
#     max_CD = max_CD % 1000
#
# max_CD
#
# AB=120
# R=100
# theta=theta
# CD=100*sin(theta)
# max_CD=100
# max_CD=100
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angles of the triangle as A, B, and C
# A, B, C = sp.symbols('A B C')
#
# try:
#     print(f"A={str(A)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"B={str(B)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"C={str(C)[:100]}")
# except:
#     pass
#
#
# # Using the Law of Sines, we know that AB / sin(C) = 2 * R
# # Therefore, sin(C) = AB / (2 * R)
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # Calculate the maximum possible value of CD which is the altitude from C to AB
# # In a right triangle ACD, CD = AC * sin(A) = AB * sin(C) * sin(A)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
# # The maximum value of CD occurs when sin(A) = 1 (i.e., A = 90 degrees)
# # In this case, CD = AB * sin(C)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
# CD_max = AB * sin_C
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Calculate the value
# CD_max_value = CD_max.evalf()
#
# try:
#     print(f"CD_max_value={str(CD_max_value)[:100]}")
# except:
#     pass
#
#
# # If the value is larger than 1 million, take modulo 1000
# if CD_max_value > 1000000:
#     CD_max_value = CD_max_value % 1000
#
# CD_max_value
#
# AB=120
# R=100
# A=A
# B=B
# C=C
# sin_C=0.6
# CD_max=72.0
# Traceback (most recent call last):
#   File "<temporary_file>", line 78, in <module>
#     CD_max_value = CD_max.evalf()
# AttributeError: 'float' object has no attribute 'evalf'
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define variables
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The circumradius R of a triangle is given by R = a/(2*sin(A)) where a is the length of the side opposite to angle A
# # For triangle ABC, we can use R = AB / (2 * sin(C))
# # Solving for sin(C)
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # Since sin(C) = opposite / hypotenuse, we need to find the greatest possible length of CD, which is the opposite side of angle C in right triangle CDB
# # The maximum value of CD occurs when angle C is 90 degrees, i.e., sin(C) = 1
# # In that case, CD = AB / 2
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
# CD_max = R * sin_C
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression
# CD_max_simplified = sp.simplify(CD_max)
#
# try:
#     print(f"CD_max_simplified={str(CD_max_simplified)[:100]}")
# except:
#     pass
#
#
# # Check if the final answer is larger than 1 million and take modulo 1000 if necessary
# final_answer = CD_max_simplified % 1000 if CD_max_simplified > 1000000 else CD_max_simplified
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
# final_answer
#
# AB=120
# R=100
# sin_C=0.6
# CD_max=60.0
# CD_max_simplified=60.0000000000000
# final_answer=60.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define variables
# AB, R = 120, 100
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
# a, b, c, h, x, y = sp.symbols('a b c h x y')
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"b={str(b)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"c={str(c)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"y={str(y)[:100]}")
# except:
#     pass
#
#
# # Given that AB = 120 and R = 100, we use the formula for the circumradius of a triangle:
# # R = abc / (4 * Area)
# # We also know that the area of the triangle can be expressed using the height (h) from C to AB:
# # Area = (1/2) * AB * h
# # Therefore, we can substitute the area in the circumradius formula:
# # R = abc / (4 * (1/2) * AB * h) => R = abc / (2 * AB * h)
#
# # For a maximum height (h), the point C should be as far from AB as possible. This happens when the triangle is isosceles
# # with AC = BC. In this case, AB = 2 * x, and the height (h) will be the other leg of the right triangle formed by
# # cutting the isosceles triangle in half. By Pythagorean theorem:
# # h^2 + x^2 = R^2
# # Given AB = 2 * x, we have x = AB / 2 = 60
#
# x = AB / 2
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
# h = sp.sqrt(R**2 - x**2)
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
#
# # Calculate the maximum height (h)
# max_h = h.evalf()
#
# try:
#     print(f"max_h={str(max_h)[:100]}")
# except:
#     pass
#
#
# # If the answer is greater than 1 million, take modulo 1000
# if max_h > 1000000:
#     max_h = max_h % 1000
#
# max_h
#
# AB=120
# R=100
# a=a
# b=b
# c=c
# h=h
# x=x
# y=y
# x=60.0
# h=80.0000000000000
# max_h=80.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the height from C to AB as h (which is CD)
# # The circumradius R is the radius of the circle that passes through all three vertices of the triangle
# # The relationship between the circumradius R, the side lengths a, b, c, and the area A of the triangle is:
# # R = abc / (4A)
# # In our case, a = 120, and the other two sides we don't know, but we can express the area in terms of h
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
#
# # The area A of the triangle can also be expressed as:
# # A = 1/2 * base * height = 1/2 * 120 * h = 60h
#
# # Now, using the circumradius formula, we have:
# # R = abc / (4A) = 120 * b * c / (4 * 60h) = 120 * b * c / (240h)
# # Simplifying, we get:
# # 100 = 120 * b * c / (240h)
# # 100 = b * c / (2h)
# # 200h = b * c
#
# # To maximize h, we need to maximize the product bc given that the triangle is a right triangle
# # In a right triangle, the hypotenuse is the diameter of the circumcircle, so the maximum length of the hypotenuse is 200
# # The maximum value of bc is when the triangle is a right triangle with hypotenuse 200
#
# # Using the Pythagorean theorem, we get:
# # 200^2 = 120^2 + b^2
# # b^2 = 200^2 - 120^2
# # b^2 = 40000 - 14400
# # b^2 = 25600
# # b = 160
#
# # Now, we can find the maximum height h:
# # 200h = 160 * 120
# # h = (160 * 120) / 200
# # h = 19200 / 200
# # h = 96
#
# # The greatest possible length of segment CD is 96
# # Since 96 is not larger than 1 million, we don't need to take modulo 1000
#
# h = 96
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
# print(h)
#
# AB=120
# R=100
# h=96
# 96
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angles of the triangle as A, B, and C
# A, B, C = sp.symbols('A B C')
#
# try:
#     print(f"A={str(A)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"B={str(B)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"C={str(C)[:100]}")
# except:
#     pass
#
#
# # Using the Law of Sines: AB / sin(C) = 2R
# # Hence, sin(C) = AB / (2R)
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # To maximize CD, C must be as large as possible, but it cannot be more than 90 degrees
# # Therefore, C should be 90 degrees, and sin(C) should be 1
# # However, sin(C) = 120 / 200 = 0.6, which is less than 1, so it's a valid triangle
#
# # When C is 90 degrees, the triangle is a right triangle with hypotenuse AB
# # And the circumradius R is the hypotenuse / 2, which is true in this case
# # So, CD is the altitude to the hypotenuse in this right triangle
# # In a right triangle, the altitude to the hypotenuse is the geometric mean of the segments of the hypotenuse
# # Let's denote the segments of the hypotenuse as x and 120 - x
# x = sp.symbols('x')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
# altitude = sp.sqrt(x * (120 - x))
#
# try:
#     print(f"altitude={str(altitude)[:100]}")
# except:
#     pass
#
#
# # To find the maximum value of altitude, we differentiate and set it to 0
# max_altitude = sp.solve(sp.diff(altitude, x), x)
#
# try:
#     print(f"max_altitude={str(max_altitude)[:100]}")
# except:
#     pass
#
# max_altitude_value = altitude.subs(x, max_altitude[0])
#
# try:
#     print(f"max_altitude_value={str(max_altitude_value)[:100]}")
# except:
#     pass
#
#
# # Convert to numerical value
# max_altitude_value = max_altitude_value.evalf()
#
# try:
#     print(f"max_altitude_value={str(max_altitude_value)[:100]}")
# except:
#     pass
#
#
# # If the value is larger than 1 million, take modulo 1000
# if max_altitude_value > 1000000:
#     max_altitude_value = max_altitude_value % 1000
#
# max_altitude_value = int(max_altitude_value)
#
# try:
#     print(f"max_altitude_value={str(max_altitude_value)[:100]}")
# except:
#     pass
#
# max_altitude_value
#
# AB=120
# R=100
# A=A
# B=B
# C=C
# sin_C=0.6
# x=x
# altitude=sqrt(x*(120 - x))
# max_altitude=[60]
# max_altitude_value=60
# max_altitude_value=60.0000000000000
# max_altitude_value=60
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let C be (x, y) and A be at (0, 0) and B at (120, 0)
# # The circumcenter is at the midpoint of the hypotenuse if the triangle is right-angled at C
# # However, we need to find the maximum length of CD, which is the altitude from C to AB
#
# # Using the circumradius formula R = (a * b * c) / (4 * Area)
# # For a right triangle, the area is (1/2) * a * b
# # Here, a = AB = 120, b = AC, and c = BC
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
# # The maximum length of CD is when C is directly above the midpoint of AB, forming a right triangle
#
# # The circumradius R is also the distance from the origin to C in this case
# # So, using the Pythagorean theorem, we can find the length of CD
# # CD = sqrt(R^2 - (AB/2)^2)
#
# # Calculate CD
# CD = sp.sqrt(R**2 - (AB/2)**2)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the result
# CD = CD.simplify()
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# CD = CD % 1000 if CD > 1000000 else CD
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Print the final result
# print(CD)
#
# AB=120
# R=100
# CD=80.0000000000000
# CD=80.0000000000000
# CD=80.0000000000000
# 80.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at C as theta
# theta = sp.symbols('theta')
#
# try:
#     print(f"theta={str(theta)[:100]}")
# except:
#     pass
#
#
# # Using the extended law of sines in triangle ABC
# # AB / sin(theta) = 2 * R
# # sin(theta) = AB / (2 * R)
# sin_theta = AB / (2 * R)
#
# try:
#     print(f"sin_theta={str(sin_theta)[:100]}")
# except:
#     pass
#
#
# # We know that the length CD is given by R * sin(theta)
# CD = R * sin_theta
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplifying the expression
# CD_simplified = sp.simplify(CD)
#
# try:
#     print(f"CD_simplified={str(CD_simplified)[:100]}")
# except:
#     pass
#
#
# # Calculate the value of CD
# CD_value = CD_simplified.evalf()
#
# try:
#     print(f"CD_value={str(CD_value)[:100]}")
# except:
#     pass
#
#
# # Since the problem asks for the greatest possible length, we take the positive value of CD
# CD_final = max(0, CD_value)
#
# try:
#     print(f"CD_final={str(CD_final)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# if CD_final > 1000000:
#     CD_final = int(CD_final) % 1000
#
# CD_final
#
# AB=120
# R=100
# theta=theta
# sin_theta=0.6
# CD=60.0
# CD_simplified=60.0000000000000
# CD_value=60.0000000000000
# CD_final=60.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # In a triangle, the circumradius R is related to the sides and the area (A) by the formula R = abc / (4A)
# # We aim to maximize CD, which is the altitude from C to AB. The area A = 1/2 * AB * CD
# # Thus, CD = 2A / AB
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Using the circumradius formula, we can express A in terms of the sides and R
# # Let BC = a, AC = b, and AB = c = 120
# # A = abc / (4R) = 120ab / (4 * 100) = 3ab / 10
#
# # To maximize CD, we need to maximize the area A, which means maximizing the product ab
# # The maximum product ab occurs when triangle ABC is isosceles, i.e., a = b
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
# # In this case, the triangle is also a right triangle (by the properties of the circumradius in a right triangle)
# # So, a = b = sqrt(c^2 - h^2) where h is the height from C to AB, which is CD
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
#
# # Since a = b, the triangle is isosceles and right, so a = b = sqrt(2) * R
# a = sp.sqrt(2) * R
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
# A = 3 * a * a / 10
#
# try:
#     print(f"A={str(A)[:100]}")
# except:
#     pass
#
# CD = 2 * A / AB
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # If the answer is larger than 1 million, take modulo 1000
# CD = CD if CD < 1000000 else CD % 1000
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# CD
#
# AB=120
# R=100
# a=100*sqrt(2)
# A=6000
# CD=100
# CD=100
# CD=100
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's define the necessary symbols
# c = sp.symbols('c')
#
# try:
#     print(f"c={str(c)[:100]}")
# except:
#     pass
#
# h = sp.symbols('h')
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
#
# # In a triangle, the relationship between the side lengths and the circumradius R is given by:
# # a/sin(A) = b/sin(B) = c/sin(C) = 2R
# # We want to maximize the height CD, which is the perpendicular from C to AB.
# # The height CD in a triangle can be given by the formula:
# # CD = c * sin(A) = c * (a / (2R))
# # Since AB = 120, and we are maximizing CD, we should consider the case when angle C is 90 degrees.
# # In this case, the triangle is a right-angled triangle and AB is the hypotenuse.
# # The maximum height CD will be the length of the altitude from C to AB.
#
# # Using the Pythagorean theorem for the right-angled triangle:
# # AB^2 = AC^2 + BC^2
# # AC^2 + BC^2 = 120^2
# # AC^2 + BC^2 = 14400
#
# # The maximum height CD is the altitude from C to AB, and for a right-angled triangle, it is given by:
# # CD = (AC * BC) / AB
# # We know that (AC * BC) = AC * sqrt(14400 - AC^2)
# # To maximize CD, we need to maximize AC * sqrt(14400 - AC^2), which is a function of AC.
#
# # Define the function to maximize
# f = c * sp.sqrt(14400 - c**2)
#
# try:
#     print(f"f={str(f)[:100]}")
# except:
#     pass
#
#
# # Take the derivative of the function with respect to c
# f_prime = sp.diff(f, c)
#
# try:
#     print(f"f_prime={str(f_prime)[:100]}")
# except:
#     pass
#
#
# # Solve for critical points
# critical_points = sp.solve(f_prime, c)
#
# try:
#     print(f"critical_points={str(critical_points)[:100]}")
# except:
#     pass
#
#
# # Evaluate the function at the critical points to find the maximum value
# max_height = 0
#
# try:
#     print(f"max_height={str(max_height)[:100]}")
# except:
#     pass
#
# for point in critical_points:
#     height = f.subs(c, point)
#     if height > max_height:
#         max_height = height
#
# # Evaluate the maximum height
# max_height = max_height.subs(c, critical_points[0])
#
# try:
#     print(f"max_height={str(max_height)[:100]}")
# except:
#     pass
#
#
# # Since the result is a symbolic expression, we need to evaluate it
# max_height = max_height.evalf()
#
# try:
#     print(f"max_height={str(max_height)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# if max_height > 1000000:
#     max_height = max_height % 1000
#
# max_height
#
# AB=120
# R=100
# c=c
# h=h
# f=c*sqrt(14400 - c**2)
# f_prime=-c**2/sqrt(14400 - c**2) + sqrt(14400 - c**2)
# critical_points=[-60*sqrt(2), 60*sqrt(2)]
# max_height=0
# max_height=7200
# max_height=7200.00000000000
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at C as theta
# theta = sp.symbols('theta')
#
# try:
#     print(f"theta={str(theta)[:100]}")
# except:
#     pass
#
#
# # Using the extended law of sines, we know that AB / sin(C) = 2R
# # Solving for sin(C), we get:
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # The maximum height (CD) is when angle C is 90 degrees or pi/2 radians
# # This is because the height is maximized when C is directly above the midpoint of AB
# # So, CD = R
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # However, we need to check if sin(C) can be 1 (which means C is 90 degrees)
# # If sin(C) > 1, then it's not possible for C to be 90 degrees
# if sin_C > 1:
#     # If sin(C) is greater than 1, the maximum height is when C is at the maximum possible angle
#     # This angle can be found using arcsin
#     max_theta = sp.asin(sin_C)
#     # The height (CD) in this case is R * cos(max_theta)
#     CD = R * sp.cos(max_theta)
# else:
#     # If sin(C) is 1 or less, the maximum height is simply R
#     CD = R
#
# # Evaluate the maximum height
# max_CD = CD.evalf()
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # If the result is greater than 1 million, take modulo 1000
# if max_CD > 1000000:
#     result = int(max_CD) % 1000
# else:
#     result = int(max_CD)
#
# result
#
# AB=120
# R=100
# theta=theta
# sin_C=0.6
# Traceback (most recent call last):
#   File "<temporary_file>", line 64, in <module>
#     max_CD = CD.evalf()
# AttributeError: 'int' object has no attribute 'evalf'
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at A and B as A and B respectively
# A, B = sp.symbols('A B')
#
# try:
#     print(f"A={str(A)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"B={str(B)[:100]}")
# except:
#     pass
#
#
# # The circumradius R is related to the sides of the triangle by the formula R = a / (2 * sin(C))
# # where a is the length of the side opposite angle C. In this case, a = AB and angle C is the angle at C.
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
#
# # We need to maximize the length of CD, which is the altitude from C to AB.
# # The length of CD can be expressed as CD = AB * sin(C).
#
# # Using the law of sines: sin(C) = AB / (2 * R)
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # Therefore, the length of CD is:
# CD = AB * sin_C
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Since we are asked for the greatest possible length of CD, we need to consider the maximum value of sin(C),
# # which is 1 (when C is 90 degrees). However, in this case, sin(C) is already determined by the given circumradius.
# # Thus, the maximum length of CD is simply the value of CD calculated above.
#
# # Calculate the numerical value of CD
# CD_value = CD.evalf()
#
# try:
#     print(f"CD_value={str(CD_value)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# CD_value_mod = int(CD_value) % 1000
#
# try:
#     print(f"CD_value_mod={str(CD_value_mod)[:100]}")
# except:
#     pass
#
#
# # Print the result
# print(CD_value_mod)
#
# AB=120
# R=100
# A=A
# B=B
# sin_C=0.6
# CD=72.0
# CD=72.0000000000000
# CD_value=72.0000000000000
# CD_value_mod=72
# 72
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Let's define the variables
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # We will use the formula for the circumradius of a triangle: R = (abc) / (4 * Area)
# # To maximize CD, we need to maximize the area of the triangle, which means making C as high above AB as possible.
# # The area of the triangle can also be given by (1/2) * base * height = (1/2) * AB * CD.
#
# # We know the circumradius (R), and the side (AB). Let's use the relationship:
# # a * b * c = 4 * R * Area
# # We want to maximize the height (CD), which is the same as maximizing the area.
# # The maximum area can be obtained when C is at the maximum possible distance from AB, which is 2 * R (the diameter).
#
# # The maximum area A_max would be (1/2) * AB * (2 * R)
# A_max = (1/2) * AB * (2 * R)
#
# try:
#     print(f"A_max={str(A_max)[:100]}")
# except:
#     pass
#
#
# # Now we use the area to find the maximum value of CD
# CD_max = (2 * A_max) / AB
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# CD_max_mod = CD_max % 1000
#
# try:
#     print(f"CD_max_mod={str(CD_max_mod)[:100]}")
# except:
#     pass
#
#
# CD_max_mod
#
# AB=120
# R=100
# A_max=12000.0
# CD_max=200.0
# CD_max_mod=200.0
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Let's denote the angle at A as alpha and at B as beta.
# # The law of sines gives us:
# # a/sin(alpha) = b/sin(beta) = c/sin(gamma) = 2R
# # where c is the side length opposite to angle gamma (angle C).
# # Since gamma = 180 - (alpha + beta) in a triangle, sin(gamma) = sin(alpha + beta).
#
# # The maximum length of CD (altitude from C to AB) can be found using the formula:
# # CD = c * sin(gamma) = AB * sin(gamma) / sin(gamma) = AB * sin(alpha + beta) / 2
# # To maximize CD, we need to maximize sin(alpha + beta), which is 1 when alpha + beta = 90 degrees.
#
# # Therefore, the maximum length of CD is AB / 2
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# CD_max = AB / 2
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Check if the answer is larger than 1 million and take modulo 1000 if necessary
# if CD_max > 1000000:
#     CD_max = CD_max % 1000
#
# CD_max
#
# AB=120
# CD_max=60.0
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# AC, BC = sp.symbols('AC BC')
#
# try:
#     print(f"AC={str(AC)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"BC={str(BC)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Using the circumradius formula: R = (abc) / (4 * Area)
# # The area (A) can be expressed using Heron's formula or using the perpendicular height CD
# # The area of the triangle can also be calculated as (1/2) * AB * CD
# # Therefore, we can express the circumradius as:
# # R = (AB * AC * BC) / (4 * (1/2 * AB * CD)) = (AC * BC) / (2 * CD)
# # Solving for CD:
# # CD = (AC * BC) / (2 * R)
#
# # Using the Pythagorean theorem in triangle ACD and BCD:
# # AD^2 + CD^2 = AC^2
# # BD^2 + CD^2 = BC^2
# # Since AD + BD = AB, and letting AD = x, then BD = 120 - x
# # We substitute AD and BD into the Pythagorean equations:
# x = sp.symbols('x')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
# AD = x
#
# try:
#     print(f"AD={str(AD)[:100]}")
# except:
#     pass
#
# BD = AB - x
#
# try:
#     print(f"BD={str(BD)[:100]}")
# except:
#     pass
#
#
# # AC^2 = AD^2 + CD^2
# AC_squared = AD**2 + CD**2
#
# try:
#     print(f"AC_squared={str(AC_squared)[:100]}")
# except:
#     pass
#
#
# # BC^2 = BD^2 + CD^2
# BC_squared = BD**2 + CD**2
#
# try:
#     print(f"BC_squared={str(BC_squared)[:100]}")
# except:
#     pass
#
#
# # Substitute AC and BC into the circumradius formula
# # CD = (AC * BC) / (2 * R)
# # (AC * BC) = 2 * R * CD
# # (AC * BC)^2 = (2 * R * CD)^2
# # (AC^2 * BC^2) = (2 * R * CD)^2
# # Substituting AC^2 and BC^2:
# # (AD^2 + CD^2) * (BD^2 + CD^2) = (2 * R * CD)^2
# # (x^2 + CD^2) * ((120 - x)^2 + CD^2) = (2 * 100 * CD)^2
# # Simplify and solve for CD
# equation = (x**2 + CD**2) * ((AB - x)**2 + CD**2) - (2 * R * CD)**2
#
# try:
#     print(f"equation={str(equation)[:100]}")
# except:
#     pass
#
#
# # Solve the equation for CD
# CD_solutions = sp.solve(equation, CD)
#
# try:
#     print(f"CD_solutions={str(CD_solutions)[:100]}")
# except:
#     pass
#
#
# # Find the maximum value of CD
# max_CD = max(CD_solutions)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
# max_CD = max_CD.evalf()
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Check if the answer is larger than 1 million and take modulo 1000 if it is
# final_answer = int(max_CD) % 1000 if max_CD > 1000000 else int(max_CD)
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
#
# final_answer
#
# AC=AC
# BC=BC
# AB=120
# R=100
# x=x
# AD=x
# BD=120 - x
# Traceback (most recent call last):
#   File "<temporary_file>", line 73, in <module>
#     AC_squared = AD**2 + CD**2
# NameError: name 'CD' is not defined. Did you mean: 'AD'?
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The circumradius R of a triangle is related to the sides by the formula R = abc / (4 * Area)
# # We want to maximize CD, the altitude from C to AB. The area of the triangle can be expressed as (1/2) * AB * CD
# # Using the formula for the area of the triangle and the circumradius, we have:
# # R = (AB * BC * CA) / (4 * (1/2) * AB * CD)
# # Simplifying, we get:
# # 2 * R * CD = BC * CA
# # We know that in a right triangle, the circumradius is half the hypotenuse, so:
# # 2 * R = AC (if AC is the hypotenuse)
#
# # Since we want to maximize CD, we consider the case where AC is the hypotenuse and triangle ABC is a right triangle.
# # In this case, AC = 2 * R = 200
#
# try:
#     print(f"AC={str(AC)[:100]}")
# except:
#     pass
#
#
# # Now, using the Pythagorean theorem in triangle ABC, we can find the length of BC:
# BC = sp.sqrt(AC**2 - AB**2)
#
# try:
#     print(f"BC={str(BC)[:100]}")
# except:
#     pass
#
#
# # Now we can find the maximum length of CD using the area formula:
# # (1/2) * AB * CD = (1/2) * BC * CA
# # AB * CD = BC * CA
# CD = (BC * AC) / AB
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Check if CD is larger than 1 million, and if so, take modulo 1000
# if CD > 1000000:
#     CD = CD % 1000
#
# CD
#
# AB=120
# R=100
# Traceback (most recent call last):
#   File "<temporary_file>", line 41, in <module>
#     BC = sp.sqrt(AC**2 - AB**2)
# NameError: name 'AC' is not defined. Did you mean: 'AB'?
# Processed prompts: 100%|██████████| 16/16 [00:43<00:00,  2.70s/it, est. speed input: 212.29 toks/s, output: 41.06 toks/s]
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Calculate sin(C) using the Law of Sines
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # Calculate the maximum possible value of CD
# # CD_max = AB * sin(C), where sin(C) = 0.6
# CD_max = AB * sin_C
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # If the value is larger than 1 million, take modulo 1000
# if CD_max > 1000000:
#     CD_max = CD_max % 1000
#
# CD_max
#
# AB=120
# R=100
# sin_C=0.6
# CD_max=72.0
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Calculate the distance from the circumcenter to the midpoint of AB
# midpoint_distance = sp.sqrt(R**2 - (AB/2)**2)
#
# try:
#     print(f"midpoint_distance={str(midpoint_distance)[:100]}")
# except:
#     pass
#
#
# # The maximum height CD is the distance from the circumcenter to the line AB
# max_CD = midpoint_distance
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Evaluate the maximum height
# max_CD_value = max_CD.evalf()
#
# try:
#     print(f"max_CD_value={str(max_CD_value)[:100]}")
# except:
#     pass
#
#
# # If the result is greater than 1 million, take modulo 1000
# if max_CD_value > 1000000:
#     result = int(max_CD_value) % 1000
# else:
#     result = int(max_CD_value)
#
# result
#
# AB=120
# R=100
# midpoint_distance=80.0000000000000
# max_CD=80.0000000000000
# max_CD_value=80.0000000000000
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# x, CD = sp.symbols('x CD')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Using the Pythagorean theorem in triangle ACD and BCD:
# # AD^2 + CD^2 = AC^2
# # BD^2 + CD^2 = BC^2
# # Since AD + BD = AB, and letting AD = x, then BD = 120 - x
# AD = x
#
# try:
#     print(f"AD={str(AD)[:100]}")
# except:
#     pass
#
# BD = AB - x
#
# try:
#     print(f"BD={str(BD)[:100]}")
# except:
#     pass
#
#
# # AC^2 = AD^2 + CD^2
# AC_squared = AD**2 + CD**2
#
# try:
#     print(f"AC_squared={str(AC_squared)[:100]}")
# except:
#     pass
#
#
# # BC^2 = BD^2 + CD^2
# BC_squared = BD**2 + CD**2
#
# try:
#     print(f"BC_squared={str(BC_squared)[:100]}")
# except:
#     pass
#
#
# # Substitute AC and BC into the circumradius formula
# # CD = (AC * BC) / (2 * R)
# # (AC * BC) = 2 * R * CD
# # (AC * BC)^2 = (2 * R * CD)^2
# # (AC^2 * BC^2) = (2 * R * CD)^2
# # Substituting AC^2 and BC^2:
# # (x^2 + CD^2) * ((120 - x)^2 + CD^2) = (2 * 100 * CD)^2
# equation = (AD**2 + CD**2) * ((AB - x)**2 + CD**2) - (2 * R * CD)**2
#
# try:
#     print(f"equation={str(equation)[:100]}")
# except:
#     pass
#
#
# # Solve the equation for CD
# CD_solutions = sp.solve(equation, CD)
#
# try:
#     print(f"CD_solutions={str(CD_solutions)[:100]}")
# except:
#     pass
#
#
# # Filter out the real solutions
# real_solutions = [sol.evalf() for sol in CD_solutions if sol.is_real]
#
# try:
#     print(f"real_solutions={str(real_solutions)[:100]}")
# except:
#     pass
#
#
# # Find the maximum value of CD
# max_CD = max(real_solutions)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Check if the answer is larger than 1 million and take modulo 1000 if it is
# final_answer = int(max_CD) % 1000 if max_CD > 1000000 else int(max_CD)
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
#
# final_answer
#
# x=x
# CD=CD
# AB=120
# R=100
# AD=x
# BD=120 - x
# AC_squared=CD**2 + x**2
# BC_squared=CD**2 + (120 - x)**2
# equation=-40000*CD**2 + (CD**2 + x**2)*(CD**2 + (120 - x)**2)
# CD_solutions=[80 - sqrt(-x**2 + 120*x + 6400), -sqrt(-x**2 + 120*x + 6400) - 80, sqrt(-x**2 + 120*x + 6400) - 80,
# real_solutions=[]
# Traceback (most recent call last):
#   File "<temporary_file>", line 108, in <module>
#     max_CD = max(real_solutions)
# ValueError: max() arg is an empty sequence
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The circumradius R of a triangle is related to the sides by the formula R = abc / (4 * Area)
# # We want to maximize CD, the altitude from C to AB. The area of the triangle can be expressed as (1/2) * AB * CD
# # Using the formula for the area of the triangle and the circumradius, we have:
# # R = (AB * BC * CA) / (4 * (1/2) * AB * CD)
# # Simplifying, we get:
# # 2 * R * CD = BC * CA
# # We know that in a right triangle, the circumradius is half the hypotenuse, so:
# # 2 * R = AC (if AC is the hypotenuse)
#
# # Since we want to maximize CD, we consider the case where AC is the hypotenuse and triangle ABC is a right triangle.
# # In this case, AC = 2 * R = 200
#
# try:
#     print(f"AC={str(AC)[:100]}")
# except:
#     pass
#
#
# AC = 2 * R
#
# try:
#     print(f"AC={str(AC)[:100]}")
# except:
#     pass
#
#
# # Now, using the Pythagorean theorem in triangle ABC, we can find the length of BC:
# BC = sp.sqrt(AC**2 - AB**2)
#
# try:
#     print(f"BC={str(BC)[:100]}")
# except:
#     pass
#
#
# # Now we can find the maximum length of CD using the area formula:
# # (1/2) * AB * CD = (1/2) * BC * CA
# # AB * CD = BC * CA
# CD = (BC * AC) / AB
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Check if CD is larger than 1 million, and if so, take modulo 1000
# if CD > 1000000:
#     CD = CD % 1000
#
# CD
#
# AB=120
# R=100
# AC=200
# BC=160
# CD=800/3
# CD=800/3
# Processed prompts: 100%|██████████| 4/4 [00:54<00:00, 13.53s/it, est. speed input: 80.69 toks/s, output: 20.58 toks/s]
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# x, CD = sp.symbols('x CD')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Using the Pythagorean theorem in triangle ACD and BCD:
# # AC^2 = AD^2 + CD^2
# # BC^2 = BD^2 + CD^2
# # Since AD + BD = AB, and letting AD = x, then BD = 120 - x
# AD = x
#
# try:
#     print(f"AD={str(AD)[:100]}")
# except:
#     pass
#
# BD = AB - x
#
# try:
#     print(f"BD={str(BD)[:100]}")
# except:
#     pass
#
#
# # AC^2 = AD^2 + CD^2
# AC_squared = AD**2 + CD**2
#
# try:
#     print(f"AC_squared={str(AC_squared)[:100]}")
# except:
#     pass
#
#
# # BC^2 = BD^2 + CD^2
# BC_squared = BD**2 + CD**2
#
# try:
#     print(f"BC_squared={str(BC_squared)[:100]}")
# except:
#     pass
#
#
# # Substitute AC and BC into the circumradius formula
# # AC * BC = 200 * CD
# equation = sp.sqrt(AC_squared) * sp.sqrt(BC_squared) - 200 * CD
#
# try:
#     print(f"equation={str(equation)[:100]}")
# except:
#     pass
#
#
# # Solve the equation for CD
# CD_solutions = sp.solve(equation, CD)
#
# try:
#     print(f"CD_solutions={str(CD_solutions)[:100]}")
# except:
#     pass
#
#
# # Filter out the real solutions
# real_solutions = [sol.evalf() for sol in CD_solutions if sol.is_real and sol > 0]
#
# try:
#     print(f"real_solutions={str(real_solutions)[:100]}")
# except:
#     pass
#
#
# # Find the maximum value of CD
# max_CD = max(real_solutions)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Check if the answer is larger than 1 million and take modulo 1000 if it is
# final_answer = int(max_CD) % 1000 if max_CD > 1000000 else int(max_CD)
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
#
# final_answer
#
# x=x
# CD=CD
# AB=120
# R=100
# AD=x
# BD=120 - x
# AC_squared=CD**2 + x**2
# BC_squared=CD**2 + (120 - x)**2
# equation=-200*CD + sqrt(CD**2 + x**2)*sqrt(CD**2 + (120 - x)**2)
# CD_solutions=[80 - sqrt(-x**2 + 120*x + 6400), -sqrt(-x**2 + 120*x + 6400) - 80, sqrt(-x**2 + 120*x + 6400) - 80,
# real_solutions=[]
# Traceback (most recent call last):
#   File "<temporary_file>", line 103, in <module>
#     max_CD = max(real_solutions)
# ValueError: max() arg is an empty sequence
# Processed prompts: 100%|██████████| 1/1 [00:51<00:00, 51.39s/it, est. speed input: 54.46 toks/s, output: 18.58 toks/s]
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# x, CD = sp.symbols('x CD')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Using the Pythagorean theorem in triangle ACD and BCD:
# # AC^2 = AD^2 + CD^2
# # BC^2 = BD^2 + CD^2
# # Since AD + BD = AB, and letting AD = x, then BD = 120 - x
# AD = x
#
# try:
#     print(f"AD={str(AD)[:100]}")
# except:
#     pass
#
# BD = AB - x
#
# try:
#     print(f"BD={str(BD)[:100]}")
# except:
#     pass
#
#
# # AC^2 = AD^2 + CD^2
# AC_squared = AD**2 + CD**2
#
# try:
#     print(f"AC_squared={str(AC_squared)[:100]}")
# except:
#     pass
#
#
# # BC^2 = BD^2 + CD^2
# BC_squared = BD**2 + CD**2
#
# try:
#     print(f"BC_squared={str(BC_squared)[:100]}")
# except:
#     pass
#
#
# # Substitute AC and BC into the circumradius formula
# # AC * BC = 200 * CD
# equation = sp.sqrt(AC_squared) * sp.sqrt(BC_squared) - 200 * CD
#
# try:
#     print(f"equation={str(equation)[:100]}")
# except:
#     pass
#
#
# # Solve the equation for CD
# CD_solutions = sp.solve(equation, CD)
#
# try:
#     print(f"CD_solutions={str(CD_solutions)[:100]}")
# except:
#     pass
#
#
# # Filter out the real solutions
# real_solutions = [sol.evalf() for sol in CD_solutions if sol.is_real and sol > 0]
#
# try:
#     print(f"real_solutions={str(real_solutions)[:100]}")
# except:
#     pass
#
#
# # Find the maximum value of CD
# max_CD = max(real_solutions)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Check if the answer is larger than 1 million and take modulo 1000 if it is
# final_answer = int(max_CD) % 1000 if max_CD > 1000000 else int(max_CD)
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
#
# final_answer
#
# x=x
# CD=CD
# AB=120
# R=100
# AD=x
# BD=120 - x
# AC_squared=CD**2 + x**2
# BC_squared=CD**2 + (120 - x)**2
# equation=-200*CD + sqrt(CD**2 + x**2)*sqrt(CD**2 + (120 - x)**2)
# CD_solutions=[80 - sqrt(-x**2 + 120*x + 6400), -sqrt(-x**2 + 120*x + 6400) - 80, sqrt(-x**2 + 120*x + 6400) - 80,
# real_solutions=[]
# Traceback (most recent call last):
#   File "<temporary_file>", line 103, in <module>
#     max_CD = max(real_solutions)
# ValueError: max() arg is an empty sequence
#
#
#
#
# ['180', '100', '60', '36', '80', '120', '7.2', '120', '36', '100', '36', '80', '72', '80', '80', '80', '100', '60', '80', '96', '60', '80', '60', '100', '7200', '72', '200', '60', '72', '80', '\\frac{800']
# 80
# 80

# %%
pd.read_csv(
    '/kaggle/input/ai-mathematical-olympiad-progress-prize-2/reference.csv'
).drop('answer', axis=1).to_csv('reference.csv', index=False)

# %%
inference_server = kaggle_evaluation.aimo_2_inference_server.AIMO2InferenceServer(
    predict)

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    inference_server.run_local_gateway((
        #             '/kaggle/input/ai-mathematical-olympiad-progress-prize-2/test.csv',
        'reference.csv', ))
# Out:
# ------
# 1acac0
# Triangle $ABC$ has side length $AB = 120$ and circumradius $R = 100$. Let $D$ be the foot of the perpendicular from $C$ to the line $AB$. What is the greatest possible length of segment $CD$?
# If the final answer is a number larger than 1 million, take modulo 1000.
# Processed prompts: 100%|██████████| 32/32 [03:16<00:00,  6.13s/it, est. speed input: 18.69 toks/s, output: 108.99 toks/s]
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# CD = sp.symbols('CD')
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The maximum length of CD occurs when C is directly above the midpoint of AB, forming a right triangle.
# # In this case, the length of the hypotenuse (AC or BC) is the circumradius R = 100.
# # The distance from the midpoint of AB to A or B is half of AB, which is 60.
# # Using the Pythagorean theorem in triangle ACD (or BCD), we can find the maximum length of CD.
#
# # Let M be the midpoint of AB, so AM = MB = AB/2 = 60
# AM = AB / 2
#
# try:
#     print(f"AM={str(AM)[:100]}")
# except:
#     pass
#
#
# # Applying the Pythagorean theorem in triangle ACM (or BCM)
# # AC^2 = AM^2 + CM^2
# # Since AC = R and CM = CD, we have:
# # R^2 = AM^2 + CD^2
# # Solving for CD
# CD_max = sp.sqrt(R**2 - AM**2)
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Evaluate the maximum length of CD
# CD_max_eval = CD_max.evalf()
#
# try:
#     print(f"CD_max_eval={str(CD_max_eval)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# CD_final = CD_max_eval % 1000 if CD_max_eval > 1000000 else CD_max_eval
#
# try:
#     print(f"CD_final={str(CD_final)[:100]}")
# except:
#     pass
#
#
# CD_final
#
# CD=CD
# AB=120
# R=100
# AM=60.0
# CD_max=80.0000000000000
# CD_max_eval=80.0000000000000
# CD_final=80.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at A as alpha and the angle at B as beta
# alpha, beta = sp.symbols('alpha beta')
#
# try:
#     print(f"alpha={str(alpha)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"beta={str(beta)[:100]}")
# except:
#     pass
#
#
# # Using the Law of Sines in triangle ABC
# # AB / sin(C) = 2 * R
# # sin(C) = AB / (2 * R)
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
# C = sp.asin(sin_C)
#
# try:
#     print(f"C={str(C)[:100]}")
# except:
#     pass
#
#
# # To maximize CD, we need to maximize the height from C to AB
# # The height CD can be expressed as R * cos(A) + R * cos(B)
# # Using the identity cos(A) + cos(B) = 1 - cos(C), we can find the maximum value of CD
# cos_C = sp.cos(C)
#
# try:
#     print(f"cos_C={str(cos_C)[:100]}")
# except:
#     pass
#
# max_CD = R * (1 - cos_C)
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for max_CD
# max_CD_simplified = sp.simplify(max_CD)
#
# try:
#     print(f"max_CD_simplified={str(max_CD_simplified)[:100]}")
# except:
#     pass
#
#
# # Evaluate the maximum length of CD
# max_CD_value = max_CD_simplified.evalf()
#
# try:
#     print(f"max_CD_value={str(max_CD_value)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# if max_CD_value > 1000000:
#     max_CD_value = max_CD_value % 1000
#
# max_CD_value
#
# AB=120
# R=100
# alpha=alpha
# beta=beta
# sin_C=0.6
# C=0.643501108793284
# cos_C=0.800000000000000
# max_CD=20.0000000000000
# max_CD_simplified=20.0000000000000
# max_CD_value=20.0000000000000
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let angle A be alpha and angle B be beta
# alpha, beta, c = sp.symbols('alpha beta c')
#
# try:
#     print(f"alpha={str(alpha)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"beta={str(beta)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"c={str(c)[:100]}")
# except:
#     pass
#
#
# # Using the Law of Sines: c/sin(C) = 2R
# # Since C = 180 - (alpha + beta), sin(C) = sin(alpha + beta)
# c = 2 * R * sp.sin(alpha + beta)
#
# try:
#     print(f"c={str(c)[:100]}")
# except:
#     pass
#
#
# # Using the Law of Cosines: c^2 = a^2 + b^2 - 2ab*cos(C)
# # Here, a = AB, b = AC, and C = 180 - (alpha + beta)
#
# try:
#     print(f"a={str(a)[:100]}")
# except:
#     pass
#
# # We can express AC in terms of AB and the angles
# b = AB / (2 * sp.cos(alpha) * sp.cos(beta))
#
# try:
#     print(f"b={str(b)[:100]}")
# except:
#     pass
#
#
# # We need to find the maximum length of CD, which is the altitude from C to AB
# # CD = b * sin(alpha)
# CD = b * sp.sin(alpha)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Substituting the expressions for b and c
# CD = CD.subs(b, AB / (2 * sp.cos(alpha) * sp.cos(beta)))
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # To find the maximum, we need to take the derivative with respect to alpha and set it to 0
# dCD_dalpha = sp.diff(CD, alpha)
#
# try:
#     print(f"dCD_dalpha={str(dCD_dalpha)[:100]}")
# except:
#     pass
#
# critical_points = sp.solve(dCD_dalpha, alpha)
#
# try:
#     print(f"critical_points={str(critical_points)[:100]}")
# except:
#     pass
#
#
# # Evaluate CD at the critical points to find the maximum
# max_CD = max([CD.subs(alpha, cp) for cp in critical_points])
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
#
# # Since the problem asks for the greatest possible length of CD, we take the maximum value
# # If the final answer is a number larger than 1 million, take modulo 1000
# max_CD = max_CD.evalf()
#
# try:
#     print(f"max_CD={str(max_CD)[:100]}")
# except:
#     pass
#
# if max_CD > 1000000:
#     max_CD = max_CD % 1000
#
# max_CD
#
# AB=120
# R=100
# alpha=alpha
# beta=beta
# c=c
# c=200*sin(alpha + beta)
# b=60/(cos(alpha)*cos(beta))
# CD=60*sin(alpha)/(cos(alpha)*cos(beta))
# CD=60*sin(alpha)/(cos(alpha)*cos(beta))
# CD=60*tan(alpha)/cos(beta)
# dCD_dalpha=60*(tan(alpha)**2 + 1)/cos(beta)
# critical_points=[]
# Traceback (most recent call last):
#   File "<temporary_file>", line 115, in <module>
#     max_CD = max([CD.subs(alpha, cp) for cp in critical_points])
# ValueError: max() arg is an empty sequence
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the symbols
# AC, BC, x, h = sp.symbols('AC BC x h')
#
# try:
#     print(f"AC={str(AC)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"BC={str(BC)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Using the circumradius formula for a triangle: R = (abc) / (4 * Area)
# # We can express the area using the base AB and the height CD (h)
# # The area is also given by (1/2) * AB * h
# # Therefore, we have: R = (AB * AC * BC) / (4 * (1/2) * AB * h) = (AC * BC) / (2 * h)
# # Solving for h, we get: h = (AC * BC) / (2 * R)
#
# # Use the Pythagorean theorem in the right triangle ACD and BCD
# # AC^2 = AD^2 + CD^2 = x^2 + h^2
# # BC^2 = BD^2 + CD^2 = (AB - x)^2 + h^2 = (120 - x)^2 + h^2
#
# # Substitute h = (AC * BC) / (2 * R) into the equations for AC and BC
# h = (AC * BC) / (2 * R)
#
# try:
#     print(f"h={str(h)[:100]}")
# except:
#     pass
#
# AC_squared = x**2 + h**2
#
# try:
#     print(f"AC_squared={str(AC_squared)[:100]}")
# except:
#     pass
#
# BC_squared = (120 - x)**2 + h**2
#
# try:
#     print(f"BC_squared={str(BC_squared)[:100]}")
# except:
#     pass
#
#
# # Law of Cosines in triangle ABC: cos(C) = (AC^2 + BC^2 - AB^2) / (2 * AC * BC)
# # cos(C) also equals AD / AC = x / AC (since D is the foot of the perpendicular from C to AB)
# cos_C = x / AC
#
# try:
#     print(f"cos_C={str(cos_C)[:100]}")
# except:
#     pass
#
# cos_C_law = (AC**2 + BC**2 - AB**2) / (2 * AC * BC)
#
# try:
#     print(f"cos_C_law={str(cos_C_law)[:100]}")
# except:
#     pass
#
#
# # Set up the equation and solve for x
# equation = sp.Eq(cos_C, cos_C_law)
#
# try:
#     print(f"equation={str(equation)[:100]}")
# except:
#     pass
#
# x_solution = sp.solve(equation, x)
#
# try:
#     print(f"x_solution={str(x_solution)[:100]}")
# except:
#     pass
#
#
# # Find the corresponding h values
# h_values = [h.subs(x, sol) for sol in x_solution]
#
# try:
#     print(f"h_values={str(h_values)[:100]}")
# except:
#     pass
#
#
# # The greatest possible length of CD is the maximum of h_values
# max_h = max(h_values)
#
# try:
#     print(f"max_h={str(max_h)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# max_h_mod = max_h % 1000 if max_h > 1000000 else max_h
#
# try:
#     print(f"max_h_mod={str(max_h_mod)[:100]}")
# except:
#     pass
#
#
# max_h_mod
#
# AC=AC
# BC=BC
# x=x
# h=h
# AB=120
# R=100
# h=AC*BC/200
# AC_squared=AC**2*BC**2/40000 + x**2
# BC_squared=AC**2*BC**2/40000 + (120 - x)**2
# cos_C=x/AC
# cos_C_law=(AC**2 + BC**2 - 14400)/(2*AC*BC)
# equation=Eq(x/AC, (AC**2 + BC**2 - 14400)/(2*AC*BC))
# x_solution=[(AC**2 + BC**2 - 14400)/(2*BC)]
# h_values=[AC*BC/200]
# max_h=AC*BC/200
# Traceback (most recent call last):
#   File "<temporary_file>", line 134, in <module>
#     max_h_mod = max_h % 1000 if max_h > 1000000 else max_h
#   File "/kaggle/usr/lib/vllm-installation-fix/sympy/core/relational.py", line 516, in __bool__
#     raise TypeError("cannot determine truth value of Relational")
# TypeError: cannot determine truth value of Relational
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The circumradius formula for a triangle is R = a * b * c / (4 * Area)
# # For a right triangle, if C is the right angle, then AB is the hypotenuse and we can use the Pythagorean theorem
# # Let AC = b and BC = c, then AB^2 = b^2 + c^2
# # The area of the right triangle is (1/2) * b * c
# # We also have the relation R = AB / 2, since the hypotenuse is the diameter of the circumcircle in a right triangle
#
# # Since R = 100 and AB = 120, the triangle is not a right triangle, so we need to consider the maximum height CD
# # The maximum height CD would be when the triangle is isosceles and CD is perpendicular to AB
# # In this case, the area of the triangle is (1/2) * AB * CD
# # Using the circumradius formula, we have R = (AB * AC * BC) / (4 * Area) = (120 * b * c) / (2 * AB * CD)
# # Simplifying, we get CD = (b * c) / (2 * R)
#
# # For an isosceles triangle, b = c and AB^2 = 2 * b^2
#
# try:
#     print(f"b={str(b)[:100]}")
# except:
#     pass
#
# # Solving for b, we get b = sqrt(AB^2 / 2)
# b = sp.sqrt(AB**2 / 2)
#
# try:
#     print(f"b={str(b)[:100]}")
# except:
#     pass
#
# CD = (b**2) / (2 * R)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Evaluate CD and take modulo 1000 if necessary
# CD_value = CD.evalf()
#
# try:
#     print(f"CD_value={str(CD_value)[:100]}")
# except:
#     pass
#
# if CD_value > 1000000:
#     CD_value = int(CD_value) % 1000
#
# CD_value
#
# AB=120
# R=100
# b=84.8528137423857
# CD=36.0000000000000
# CD=36.0000000000000
# CD_value=36.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the variables
# R, AB, CD = 100, 120, sp.symbols('CD')
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # The area of the triangle can be expressed in two ways:
# # 1. Using the circumradius R and the sides (ABC)
# # 2. Using the base AB and the height CD
# # Area = (AB * CD) / 2
#
# # From the circumradius, we know that the area can also be written as:
# # Area = (AB * BC * CA) / (4 * R)
#
# # Using the maximum possible length of segment CD (i.e., when triangle ABC is right-angled at C)
# # We get BC = sqrt(AB^2 + CD^2) and CA = sqrt(AB^2 + CD^2) as well
#
# # Let's calculate the maximum length of CD
# # In a right-angled triangle, the circumradius R is half the hypotenuse:
# # R = hypotenuse / 2
# # hypotenuse = 2 * R = 200
#
# # The maximum length of CD occurs when CD is perpendicular to AB and triangle ABC is right-angled at C
# # Using the Pythagorean theorem:
# # AB^2 + CD^2 = hypotenuse^2
# # CD^2 = hypotenuse^2 - AB^2
# # CD = sqrt(hypotenuse^2 - AB^2)
#
# CD_max = sp.sqrt((2 * R)**2 - AB**2)
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Check if the result is greater than 1 million
# if CD_max > 1000000:
#     CD_max = CD_max % 1000
#
# CD_max
#
# R=100
# AB=120
# CD=CD
# CD_max=160
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let's denote the angle at C as γ. The circumradius R is related to the side lengths and the angle by the formula:
# # R = AB / (2 * sin(γ))
#
# # From the above, we can solve for sin(γ):
# sin_gamma = AB / (2 * R)
#
# try:
#     print(f"sin_gamma={str(sin_gamma)[:100]}")
# except:
#     pass
#
#
# # The height CD from C to AB can be found using the formula for the area of the triangle:
# # Area = 0.5 * base * height = 0.5 * AB * CD
# # But the area can also be expressed using AB, AC, and the sine of the angle between them:
# # Area = 0.5 * AB * AC * sin(γ)
#
# # To maximize CD, we consider the maximum value of AC, which is 2R (diameter of the circumcircle)
# AC_max = 2 * R
#
# try:
#     print(f"AC_max={str(AC_max)[:100]}")
# except:
#     pass
#
#
# # Now calculate the maximum height CD:
# CD_max = AC_max * sin_gamma
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Since we need to take the result modulo 1000 if it's larger than 1 million, we compute:
# CD_max_mod = CD_max % 1000
#
# try:
#     print(f"CD_max_mod={str(CD_max_mod)[:100]}")
# except:
#     pass
#
#
# CD_max_mod
#
# AB=120
# R=100
# sin_gamma=0.6
# AC_max=200
# CD_max=120.0
# CD_max_mod=120.0
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let the angle at C be θ (in radians)
# θ = sp.symbols('θ')
#
# try:
#     print(f"θ={str(θ)[:100]}")
# except:
#     pass
#
#
# # Using the extended law of sines: AB / sin(θ) = 2R
# sin_θ = AB / (2 * R)
#
# try:
#     print(f"sin_θ={str(sin_θ)[:100]}")
# except:
#     pass
#
#
# # Solving for θ
# θ = sp.asin(sin_θ)
#
# try:
#     print(f"θ={str(θ)[:100]}")
# except:
#     pass
#
#
# # The length of CD is given by R * cos(θ/2) (since D is the foot of the perpendicular from C to AB)
# CD = R * sp.cos(θ / 2)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Evaluate the expression to get the numerical value
# CD_value = CD.evalf()
#
# try:
#     print(f"CD_value={str(CD_value)[:100]}")
# except:
#     pass
#
#
# # If the value is greater than 1 million, take modulo 1000
# if CD_value > 1000000:
#     CD_value = CD_value % 1000
#
# CD_value
#
# AB=120
# R=100
# θ=θ
# sin_θ=0.6
# θ=0.643501108793284
# CD=94.8683298050514
# CD=94.8683298050514
# CD_value=94.8683298050514
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let the coordinates of A and B be (0, 0) and (120, 0) respectively.
# # The circumcenter O of the triangle ABC is at the midpoint of AB and at height R from the line AB.
# # Therefore, the coordinates of O are (60, 0).
#
# # The coordinates of C can be (60, y) or (60, -y) since the distance from O to C is R.
# # The length of CD is the absolute value of the y-coordinate of C, which is the same as the distance from C to the line AB.
#
# # Using the Pythagorean theorem in the right triangle OAC, we have:
# # OC^2 = OA^2 + AC^2
# # R^2 = 60^2 + y^2
# # 100^2 = 60^2 + y^2
# # y^2 = 100^2 - 60^2
# # y^2 = 10000 - 3600
# # y^2 = 6400
# # y = 80 or y = -80
#
# # The greatest possible length of segment CD is the maximum of |y|, which is 80.
# CD = 80
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000.
# # Since 80 is not larger than 1 million, we don't need to take modulo 1000.
# final_answer = CD
#
# try:
#     print(f"final_answer={str(final_answer)[:100]}")
# except:
#     pass
#
#
# final_answer
#
# AB=120
# R=100
# CD=80
# final_answer=80
#
#
#
# ceimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let C be (x, y) in the coordinate plane, with A at (0, 0) and B at (120, 0)
# # The circumcenter O is at (60, 0) because it must be equidistant from A and B
# # The distance from O to C is the circumradius R = 100
# # So, the equation of the circle with center (60, 0) and radius R is (x - 60)^2 + y^2 = 100^2
#
# # Define the variables
# x, y = sp.symbols('x y')
#
# try:
#     print(f"x={str(x)[:100]}")
# except:
#     pass
#
#
# try:
#     print(f"y={str(y)[:100]}")
# except:
#     pass
#
#
# # Equation of the circle
# circle_eq = (x - 60)**2 + y**2 - 100**2
#
# try:
#     print(f"circle_eq={str(circle_eq)[:100]}")
# except:
#     pass
#
#
# # Solve for y in terms of x
# y_expr = sp.solve(circle_eq, y)
#
# try:
#     print(f"y_expr={str(y_expr)[:100]}")
# except:
#     pass
#
#
# # The length of CD is the y-coordinate of C because D is the foot of the perpendicular from C to AB
# # So, CD is maximized when y is maximized. We take the positive root of y
# y_max = max(y_expr)
#
# try:
#     print(f"y_max={str(y_max)[:100]}")
# except:
#     pass
#
#
# # Substitute x = 60 to find the maximum y (since the circle is symmetric about x = 60)
# CD_max = y_max.subs(x, 60)
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression
# CD_max = sp.simplify(CD_max)
#
# try:
#     print(f"CD_max={str(CD_max)[:100]}")
# except:
#     pass
#
#
# # If the final answer is a number larger than 1 million, take modulo 1000
# if CD_max > 1000000:
#     CD_max = CD_max % 1000
#
# CD_max
#
# AB=120
# R=100
# x=x
# y=y
# circle_eq=y**2 + (x - 60)**2 - 10000
# y_expr=[-sqrt(-(x - 160)*(x + 40)), sqrt(-(x - 160)*(x + 40))]
# Traceback (most recent call last):
#   File "<temporary_file>", line 62, in <module>
#     y_max = max(y_expr)
#   File "/kaggle/usr/lib/vllm-installation-fix/sympy/core/relational.py", line 516, in __bool__
#     raise TypeError("cannot determine truth value of Relational")
# TypeError: cannot determine truth value of Relational
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Given values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Let the angle at C be θ (theta)
# theta = sp.symbols('theta')
#
# try:
#     print(f"theta={str(theta)[:100]}")
# except:
#     pass
#
#
# # Using the circumradius formula: R = AB / (2 * sin(θ))
# # Solving for sin(θ)
# sin_theta = AB / (2 * R)
#
# try:
#     print(f"sin_theta={str(sin_theta)[:100]}")
# except:
#     pass
#
# cos_theta = sp.sqrt(1 - sin_theta**2)
#
# try:
#     print(f"cos_theta={str(cos_theta)[:100]}")
# except:
#     pass
#
#
# # The length of CD is given by R * cos(θ)
# CD = R * cos_theta
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Evaluate the length of CD
# CD_value = CD.evalf()
#
# try:
#     print(f"CD_value={str(CD_value)[:100]}")
# except:
#     pass
#
#
# # Check if the final answer is a number larger than 1 million
# if CD_value > 1000000:
#     CD_value = CD_value % 1000
#
# # Final answer
# CD_value
#
# AB=120
# R=100
# theta=theta
# sin_theta=0.6
# cos_theta=0.800000000000000
# CD=80.0000000000000
# CD=80.0000000000000
# CD_value=80.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the known values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # The circumradius R of a triangle is given by R = a / (2 * sin(A))
# # where a is the side opposite to angle A. Here, AB is the side opposite to angle C.
# # We can use the formula for the circumradius to find sin(C)
#
# # Let C be the angle opposite to AB
# sin_C = AB / (2 * R)
#
# try:
#     print(f"sin_C={str(sin_C)[:100]}")
# except:
#     pass
#
#
# # Since sin^2(C) + cos^2(C) = 1, we can find cos(C)
# cos_C = sp.sqrt(1 - sin_C**2)
#
# try:
#     print(f"cos_C={str(cos_C)[:100]}")
# except:
#     pass
#
#
# # The length of CD is the altitude from C to AB, which is given by AB * sin(C)
# CD = AB * cos_C
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Since the problem asks for the greatest possible length, we take the positive value of cos(C)
# # and if the value is larger than 1 million, take modulo 1000
# CD = CD % 1000
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Print the result
# CD
#
# AB=120
# R=100
# sin_C=0.6
# cos_C=0.800000000000000
# CD=96.0000000000000
# CD=96.0000000000000
# CD=96.0000000000000
#
#
#
# coimport math
# import numpy as np
# import sympy as sp
# import sympy as sp
#
# # Define the known values
# AB = 120
#
# try:
#     print(f"AB={str(AB)[:100]}")
# except:
#     pass
#
# R = 100
#
# try:
#     print(f"R={str(R)[:100]}")
# except:
#     pass
#
#
# # Define the variables
# C = sp.Symbol('C')
#
# try:
#     print(f"C={str(C)[:100]}")
# except:
#     pass
#
# CD = sp.Symbol('CD')
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # The length of the altitude CD from C to AB in a triangle can be derived using the formula:
# # CD = 2 * Area / AB, where Area = (1/2) * AB * CD
# # We also know that the circumradius R can be expressed using the formula:
# # R = (AB * BC * CA) / (4 * Area)
#
# # The maximum possible length of CD occurs when angle ACB is 90 degrees, making triangle ABC a right triangle.
# # In a right triangle, the circumradius R is half the hypotenuse, so the hypotenuse AC or BC (depending on which is the hypotenuse) is 2R.
# # If we assume AC is the hypotenuse, then AC = 2R = 200.
#
# # Using the Pythagorean theorem in the right triangle ABC:
# # AC^2 = AB^2 + BC^2
# # 200^2 = 120^2 + BC^2
# BC = sp.sqrt(200**2 - 120**2)
#
# try:
#     print(f"BC={str(BC)[:100]}")
# except:
#     pass
#
#
# # Now, the area of the triangle ABC can be calculated as:
# Area = (1/2) * AB * BC
#
# try:
#     print(f"Area={str(Area)[:100]}")
# except:
#     pass
#
#
# # Using the formula for the altitude CD:
# CD = (2 * Area) / AB
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Simplify the expression for CD
# CD = sp.simplify(CD)
#
# try:
#     print(f"CD={str(CD)[:100]}")
# except:
#     pass
#
#
# # Check if the result is greater than 1 million and take modulo 1000 if it is
# if CD > 1000000:
#     result = CD % 1000
# else:
#     result = CD
#
# result = int(result)  # Convert to integer as the problem expects a number
#
# try:
#     print(f"result={str(result)[:100]}")
# except:
#     pass
#
#
# result
#
# AB=120
# R=100
# C=C
# CD=CD
# BC=160
# Area=9600.00000000000
# CD=160.000000000000
# CD=160.000000000000
# result=160
# Processed prompts: 100%|██████████| 13/13 [01:06<00:00,  5.08s/it, est. speed input: 114.96 toks/s, output: 39.39 toks/s]
# ['100', '{{int(CD_length)', '72', '36', '128', '100', '80', '180', '120', '150', '150', '{{int(CD_max)', '60', '160', '200', '100', '{{max_CD_mod', '103', '80', '80', '20', '80', '180', '36', '160', '120', '94.8683298050514', '80', '100', '80', '96', '160']
# 80
#
#
#
# Triangle $ABC$ has side length $AB = 120$ and circumradius $R = 100$. Let $D$ be the foot of the perpendicular from $C$ to the line $AB$. What is the greatest possible length of segment $CD$?
# ------
#
#
#
# ------
# 057f8a
# Three airline companies operate flights from Dodola island. Each company has a different schedule of departures. The first company departs every 100 days, the second every 120 days and the third every 150 days. What is the greatest positive integer $d$ for which it is true that there will be $d$ consecutive days without a flight from Dodola island, regardless of the departure times of the various airlines?
# ------
#
#
#
# ------
# 88c219
# For positive integers $x_1,\ldots, x_n$ define $G(x_1, \ldots, x_n)$ to be the sum of their $\frac{n(n-1)}{2}$ pairwise greatest common divisors. We say that an integer $n \geq 2$ is \emph{artificial} if there exist $n$ different positive integers $a_1, ..., a_n$ such that
# \[a_1 + \cdots + a_n = G(a_1, \ldots, a_n) +1.\]
# Find the sum of all artificial integers $m$ in the range $2 \leq m \leq 40$.
# ------
#
#
#
# ------
# 349493
# We call a sequence $a_1, a_2, \ldots$ of non-negative integers \textit{delightful} if there exists a positive integer $N$ such that for all $n > N$, $a_n = 0$, and for all $i \geq 1$, $a_i$ counts the number of multiples of $i$ in $a_1, a_2, \ldots, a_N$. How many delightful sequences of non-negative integers are there?
# ------
#
#
#
# ------
# 192e23
# Fred and George take part in a tennis tournament with $4046$ other players. In each round, the players are paired into $2024$ matches. How many ways are there to arrange the first round such that Fred and George do not have to play each other? (Two arrangements for the first round are \textit{different} if there is a player with a different opponent in the two arrangements.)
# ------
#
#
#
# ------
# a1d40b
# The Fibonacci numbers are defined as follows: $F_0 = 0$, $F_1 = 1$, and $F_{n+1} = F_n + F_{n-1}$ for $n \geq 1$. There are $N$ positive integers $n$ strictly less than $10^{101}$ such that $n^2 + (n+1)^2$ is a multiple of 5 but $F_{n-1}^2 + F_n^2$ is not. How many prime factors does $N$ have, counted with multiplicity?
# ------
#
#
#
# ------
# 71beb6
# For a positive integer $n$, let $S(n)$ denote the sum of the digits of $n$ in base 10. Compute $S(S(1)+S(2)+\cdots+S(N))$ with $N=10^{100}-2$.
# ------
#
#
#
# ------
# 1fce4b
# Find the three-digit number $n$ such that writing any other three-digit number $10^{2024}$ times in a row and $10^{2024}+2$ times in a row results in two numbers divisible by $n$.
# ------
#
#
#
# ------
# bbd91e
# Alice writes all positive integers from $1$ to $n$ on the board for some positive integer $n \geq 11$. Bob then erases ten of them. The mean of the remaining numbers is $3000/37$. The sum of the numbers Bob erased is $S$. What is the remainder when $n \times S$ is divided by $997$?
# ------
#
#
#
# ------
# 480182
# Let $ABC$ be a triangle with $BC=108$, $CA=126$, and $AB=39$. Point $X$ lies on segment $AC$ such that $BX$ bisects $\angle CBA$. Let $\omega$ be the circumcircle of triangle $ABX$. Let $Y$ be a point on $\omega$ different from $X$ such that $CX=CY$. Line $XY$ meets $BC$ at $E$. The length of the segment $BE$ can be written as $\frac{m}{n}$, where $m$ and $n$ are coprime positive integers. Find $m+n$.
# ------
